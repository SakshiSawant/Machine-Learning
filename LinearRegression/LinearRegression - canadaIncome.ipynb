# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("F:\MachineLearning\canada_per_capita_income.csv")
df.head(3)
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income(US$)')
plt.scatter(df.year,df.income, color='red',marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df.income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income(US$)')
plt.scatter(df.year,df.income, color='red',marker='+')
plt.plot(df.year,reg.predict(df[['year']]),color='blue')
